# %%
import os
os.chdir('/ssd_Samsung870_2T/nnUNet/nnunet')

# %%
main_dir = os.path.join("/ssd_Samsung870_2T",'nnUNet/nnunet')
os.environ['nnUNet_raw_data_base'] = os.path.join(main_dir,'nnUNet_raw_data_base')
os.environ['nnUNet_preprocessed'] = os.path.join(main_dir,'preprocessed')
os.environ['RESULTS_FOLDER'] = os.path.join(main_dir,'nnUNet_trained_models')

# %%
# !nnUNet_plan_and_preprocess -t 777

# %%
# !nnUNet_train 3d_fullres nnUNetTrainerV2_insaneDA 777 0

# %%
# !nnUNet_train 3d_fullres nnUNetTrainerV2_insaneDA 777 4 -val

# %%
# !nnUNet_determine_postprocessing -h

# %%
# !nnUNet_determine_postprocessing -t 777 -tr nnUNetTrainerV2_insaneDA -m 3d_fullres

# %%
# !nnUNet_predict -i /ssd_Samsung870_2T/nnUNet_result/0811forinference/realT2_flipped_AP/ -o /ssd_Samsung870_2T/nnUNet_result/0811realT2result/realT2_flipped_AP/ -t 777 -tr nnUNetTrainerV2_insaneDA -m 3d_fullres
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /ssd_Samsung870_2T/nnUNet/nnunet/nnUNet_trained_models/nnUNet/3d_fullres/Task777/nnUNetTrainerV2_insaneDA__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 210 unique case ids, here are some examples: ['crossmoda2022_etz_147_AP' 'crossmoda2021_ldn_172_AP'
#  'crossmoda2022_etz_176_AP' 'crossmoda2022_etz_201_AP'
#  'crossmoda2021_ldn_162_AP' 'crossmoda2022_etz_204_AP'
#  'crossmoda2021_ldn_118_AP' 'crossmoda2021_ldn_180_AP'
#  'crossmoda2022_etz_127_AP' 'crossmoda2021_ldn_170_AP']
# ...

# %%
# !nnUNet_predict -i /ssd_Samsung870_2T/nnUNet_result/0811forinference/realT2_flipped_IS/ -o /ssd_Samsung870_2T/nnUNet_result/0811realT2result/realT2_flipped_IS/ -t 777 -tr nnUNetTrainerV2_insaneDA -m 3d_fullres
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /ssd_Samsung870_2T/nnUNet/nnunet/nnUNet_trained_models/nnUNet/3d_fullres/Task777/nnUNetTrainerV2_insaneDA__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 210 unique case ids, here are some examples: ['crossmoda2022_etz_151_IS' 'crossmoda2022_etz_142_IS'
#  'crossmoda2021_ldn_201_IS' 'crossmoda2021_ldn_114_IS'
#  'crossmoda2022_etz_163_IS' 'crossmoda2021_ldn_142_IS'
#  'crossmoda2021_ldn_169_IS' 'crossmoda2022_etz_106_IS'
#  'crossmoda2022_etz_183_IS' 'crossmoda2021_ldn_202_IS']
# ...

# %%
# !nnUNet_predict -i /ssd_Samsung870_2T/nnUNet_result/0811forinference/realT2_flipped_LR/ -o /ssd_Samsung870_2T/nnUNet_result/0811realT2result/realT2_flipped_LR/ -t 777 -tr nnUNetTrainerV2_insaneDA -m 3d_fullres
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /ssd_Samsung870_2T/nnUNet/nnunet/nnUNet_trained_models/nnUNet/3d_fullres/Task777/nnUNetTrainerV2_insaneDA__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 210 unique case ids, here are some examples: ['crossmoda2022_etz_171_LR' 'crossmoda2022_etz_128_LR'
#  'crossmoda2022_etz_148_LR' 'crossmoda2021_ldn_164_LR'
#  'crossmoda2022_etz_207_LR' 'crossmoda2021_ldn_130_LR'
#  'crossmoda2021_ldn_199_LR' 'crossmoda2022_etz_126_LR'
#  'crossmoda2022_etz_149_LR' 'crossmoda2021_ldn_134_LR']
# ...

# %%
# !nnUNet_predict -i /ssd_Samsung870_2T/nnUNet_result/0811forinference/realT2_noisy/ -o /ssd_Samsung870_2T/nnUNet_result/0811realT2result/realT2_noisy/ -t 777 -tr nnUNetTrainerV2_insaneDA -m 3d_fullres
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /ssd_Samsung870_2T/nnUNet/nnunet/nnUNet_trained_models/nnUNet/3d_fullres/Task777/nnUNetTrainerV2_insaneDA__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 210 unique case ids, here are some examples: ['crossmoda2021_ldn_162_noisy' 'crossmoda2021_ldn_138_noisy'
#  'crossmoda2022_etz_132_noisy' 'crossmoda2022_etz_111_noisy'
#  'crossmoda2022_etz_123_noisy' 'crossmoda2022_etz_144_noisy'
#  'crossmoda2022_etz_190_noisy' 'crossmoda2021_ldn_162_noisy'
#  'crossmoda2022_etz_132_noisy' 'crossmoda2022_etz_108_noisy']
# ...

# %%
os.environ['PATH_TO_VAL'] = os.path.join('/ssd_Samsung870_2T/nnUNet/nnunet/nnUNet_raw_data_base/nnUNet_raw_data/Task777/imagesTs')
os.environ['PATH_TO_PUT'] = os.path.join('/ssd_Samsung870_2T/test_result')

# %%
# !docker load -i /ssd_Samsung870_2T/test_docker/test_docker3.tar

# %%
# !docker run --shm-size 64G --gpus all -it --rm test_4
